# %% [markdown]
# ![Screenshot 2026-01-30 213650.png](attachment:2651cb5f-007c-4eec-8f3e-f17aa92cd030.png)

# %% [markdown]
# ![Screenshot 2026-01-30 213709.png](attachment:a1697059-eeda-4026-a811-9e840754e5f0.png)

# %% [markdown]
# ![Screenshot 2026-01-30 213731.png](attachment:f30a5e1c-236a-4d72-a002-3ac69b979e74.png)

# %%
# Python code below
# Use print("messages...") to debug your solution.

show_expected_result = False
show_hints = False

words = [
    "able lost darkness learn",
    "road older goes",
    "basic",
    "must seed laid itself hot must",
    "compound decide",
    "trap active paragraph hair review stay written",
    "facing smile vowel chose other",
    "occur shop box metal equal mouse some city"
]
# insert code
most = [len(i.split()) for i in words]
max(most)
# Out:
# 8
