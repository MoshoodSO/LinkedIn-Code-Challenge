# %% [markdown]
# ![shape1.png](attachment:c2bcc8fb-5dee-47ae-8f4b-4583b6092b45.png)

# %% [markdown]
# ![shape2.png](attachment:345eed13-c547-46fe-ba89-1f56c8110965.png)

# %%
# Python code‌ below
class Shape:
    width = 5
    height = 6
    printChar = '#'

    def printRow(self, i):
        raise NotImplementedError("Will be implemented by children extending this class")

    def print(self):
        for i in range(self.height):
            self.printRow(i)


class Square(Shape):
	def printRow(self, i):
		print(self.printChar * self.width)


class Triangle(Shape):
    def printRow(self, i):
        print(self.printChar * (i+1))


class SymmTriangle(Shape):
    height = 
    width = 6
    
    def printRow(self, i):
        
        triangleWidth = i * 2 + 1
        padding = int((self.width - triangleWidth)/2)
        print(' '*padding + self.printChar *triangleWidth)

# %%
t = Triangle()
t.print()
# Out:
# #
# ##
# ###
# ####
# #####
# ######

# %%
s = Square()
s.print()
# Out:
# #####
# #####
# #####
# #####
# #####
# #####

# %%
p = Shape()
p.print(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 p = Shape()
# ----> 2 p.print(7)
#
# TypeError: Shape.print() takes 1 positional argument but 2 were given

# %%
sym = SymmTriangle()
sym.print()
# Out:
#     #
#         ###
#                  #####
#                                     #######
#                                                                            #########
#                                                                                                                                                           ###########
