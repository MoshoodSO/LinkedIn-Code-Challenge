# %% [markdown]
# ![Screenshot 2026-01-28 205315.png](attachment:159cda05-66d1-401d-b697-4eabf8791c2e.png)

# %% [markdown]
# ![Screenshot 2026-01-28 205347.png](attachment:84e6abae-39c6-4a71-b5a3-b0745cbd58c9.png)

# %%
def square(num):
    '''
    Returns a generator of object with of the square of numbers from 1 to the number

    Args:
        num (int): A positive whole number

    Returns:
        generator: a genetor with each number in a range square.

    Examples:
    >>> square(5)
    >>> [1, 4, 9, 16]

    >>> square(20)
    >>> [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361]
    '''
    return [i**2 for i in range(1,num)]

# %%
square(5)
# Out:
# [1, 4, 9, 16]

# %%
square(10)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]
